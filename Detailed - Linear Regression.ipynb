# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.getcwd()
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_boston

# %%
df=load_boston()

# %%
type(df)
# Out:
# sklearn.utils.Bunch

# %%
df.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
# Lets Explore the data

# %%
print(df.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(df.data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(df.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
print(df.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# # Preparing teh Dataset

# %%
data=pd.DataFrame(df.data,columns= df.feature_names)

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data["Price"]= df.target

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# # Summerizing the sats

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Check the Missing Values

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - In case of regression problem the first thing to check is corelation
#
# - To check how independed and output features are related if they are highly corelated positve of negative the model will perform better. This is important in case of linear regresssion

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# # By default selection in corr function is pearson. What does pearson co relation does?
# - it checks the relation ship between two features such that wheather it is highly positively or negatively corelated or not corelated at all. Usually the output in this ranges between -1 to 1.
# - Value more towards -1 is the features are highly negitively co related
# - Value more towards 1 is the features are highly poitively co related
# - Value more towards 0 is the features are not co related

# %% [markdown]
# ### We need to check 2 correlations in LInear Regression
#
# - 1. co relation between dependent and independent variables - will plot heatmap or scatter plot to check the relationship
# - 2. corr betwwen independed variables - If there is high co relation between 2 features we will have to remove one feature as it is what we call multicolinearity

# %%
# pairplot to check if there is positve or negative corelation

# %%
sns.pairplot(data)

# %%
plt.scatter(data["CRIM"],data["Price"])
plt.xlabel("Crime Rate")
plt.ylabel ("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(data["RM"],data["Price"])
plt.xlabel("Avg. no of Rooms")
plt.ylabel ("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x="RM",y="Price", data= data)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x="LSTAT",y="Price", data= data)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='Price'>

# %%
sns.regplot(x="CHAS",y="Price", data= data)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='Price'>

# %%
sns.regplot(x="PTRATIO",y="Price", data= data)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='Price'>

# %% [markdown]
# Conclusion:
# - price and crime inversly corelated as crime incresed price decreases
# - room and price are corelated as room size increases price increase
# - PT ratio decreses price increases

# %% [markdown]
# # We are able to create simple linear regression line
# - with price and rooms There is positve co relation
# - LSTAT and price neg corealtion
# - CHAS and price no coreation
#
# Important to have linearity in data or inverse relationship atleast for data to perform well in linear regresssion. If there is data like senerio 3 where it is not co reated it reduces the error of regression model

# %% [markdown]
# ### Dividing the features into Independent and dependent feature

# %%
x = data.iloc[:,0:-1]
y = data["Price"]

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
## Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (354, 13)

# %%
y_test.shape
# Out:
# (152,)

# %% [markdown]
# # why Standardisation important?
#
# - Internally we use gradient descent in LR. The main aim of Linear regression is to come near to global minima and for this we have to make sure all out independent features we use are in same scale. The conversion will make GD faster so we have to standardise the data.

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %% [markdown]
# # Fit_transform is apply standardization on data and transform is to transform it completely to the same scale

# %%
x_train= sc.fit_transform(x_train)

# %% [markdown]
# - fit : Learn and estimate the parameters of the transformation
# - fit :  Apply the learned transformation to new data
# - fit : Learn the parameters and apply the transformation to new data
#
# - Suppose we have a dataset train_data for training and test_data for testing. We can use fit() to learn the parameters from the training data (estimator.fit(train_data)) and then use transform() to apply the learned transformation to the test data (transformed_data = estimator.transform(test_data)). Alternatively, we can use fit_transform() to perform both steps in one (transformed_data = estimator.fit_transform(data)).

# %% [markdown]
# ## for x test we dont have to apply fit _transfer just transform because the parameter has already learned pattern from train data so just transform. This is also done because we dont want to apply same technique on test data set what we have already applied on train data set this is done because we dont want our model to know much information about test data set

# %%
x_test = sc.transform(x_test)

# %% [markdown]
# # MODEL tRAINING

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Print Intercept and coefficents two main things of Linear Regression

print(lr.coef_)
# Out:
# [-1.10834602  0.80843998  0.34313466  0.81386426 -1.79804295  2.913858
#  -0.29893918 -2.94251148  2.09419303 -1.44706731 -2.05232232  1.02375187
#  -3.88579002]

# %% [markdown]
# # The coeeficent values are basically coefficents of the independent variables. So if we read it the first value which stands for CRIM imples that with every unit increase in CRIM value there will be -1.08 % decrease in property price

# %%
print(lr.intercept_)
# Out:
# 23.01581920903955

# %%
# Checking Parameters on which model is trained

# %%
lr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
# Prediction with Test Data

# %%
x_test_pred=lr.predict(x_test)

# %% [markdown]
# ### whenever we get any preddictions we can compare with y test information. To check this we will plot below daiagrams which will give fair idea if model has performed good or bad

# %% [markdown]
# # Assumptions

# %% [markdown]
# # 1. Plot a scatter plot

# %%
plt.scatter(y_test,x_test_pred)

# %% [markdown]
# ### Conclusion: When predicted values show linearity like in above daigram means out model has performed well

# %%
residuals = y_test-x_test_pred

# %%
residuals
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: Price, Length: 152, dtype: float64

# %% [markdown]
# # plotting residuals

# %%
sns.distplot(residuals)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## Predictions and Residuals :

# %%
plt.scatter(x_test_pred,residuals)

# %% [markdown]
# ### Conclusion: The scatter are not following any pattern. The points are scattered uniformly. Uniform distribuation is basically there with respect to test data and residuals

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
mse = mean_absolute_error(y_test,x_test_pred)
print("Mean Absolute Error :", mse)
# Out:
# Mean Absolute Error : 3.1627098714574053

# %%
squ= mean_squared_error(y_test,x_test_pred)
print("Mean Squared Error ", squ)
# Out:
# Mean Squared Error  21.5174442311772

# %%
rmse = np.sqrt(mean_squared_error(y_test,x_test_pred))
print(" Root Mean Square Error", rmse)
# Out:
#  Root Mean Square Error 4.63868992617282

# %%
# The above values will indicate how my model is performing

# %% [markdown]
# # Checking Accuracy

# %% [markdown]
# # R2 and Adjusted R2
#
# $ R^2 = 1-SSR/SST $
#
# $R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of squares

# %%
# Adjusted R2 will be less than R2 alwaysabs

from sklearn.metrics import r2_score

r_score = r2_score(y_test,x_test_pred)
print(r_score)
# Out:
# 0.7112260057484934

# %% [markdown]
# # Adjusted R2

# %% [markdown]
# $ Adjusted R2 = 1 -[(1-R^2)*(n-1)/(n-k-1)$
#
# - R2 : The R^2 score of the model
# - n : Number of observation
# - k : The number of predictor variables

# %% [markdown]
# code = 1 - (1-model.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1)

# %%
1 - (1-r_score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.6840226584639312

# %% [markdown]
# # New Data Prediction

# %%
df.data[0].shape
# Out:
# (13,)

# %%
df.data[0].reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %% [markdown]
# # Before predicting new data do standardisation

# %%
sc.transform(df.data[0].reshape(1,-1))
# Out:
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
lr.predict(sc.transform(df.data[0].reshape(1,-1)))
# Out:
# array([30.08649576])

# %%
https://www.youtube.com/watch?v=MJ1vWb1rGwM&t=2214s
